# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
print(df.columns)
# Out:
# Index(['title', 'start datetime', 'end datetime', 'Session Type',
#        '# CEs Needed', 'Day', 'Sobia Ansari', 'Christina Chen', 'John Butos',
#        'Elaine Chen', 'Teresa Davis', 'Caspian Folmsbee', 'Katarzyna Gore',
#        'Stephen Gore', 'Anne Hartley', 'Scott Heinrich', 'Suchita Kishore',
#        'Matthew Kuhns', 'Carl Lambert', 'Jill Marcus', 'Irena Medenica',
#        'Sameer Panjwani', 'Melissa Rice', 'Sara Ruddock-Walker', 'Syed Shah',
#        'Andrew Simms', 'Tina Sundarum', 'Paola Susan', 'Frank Tenuto',
#        'Christine Tsai', 'Brett Williams', 'Elif Yucebay', 'Rahul Patwari',
#        'Total Column', 'Back Up', 'Scheduler', 'Reviewer', 'Notes',
#        'AS Changes', 'Groups'],
#       dtype='object')

# %%
df.drop(['ii', 'jj','kk', 'll', 'mm', 'nn', 'oo', 'pp'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df.drop(['ii', 'jj','kk', 'll', 'mm', 'nn', 'oo', 'pp'], axis=1, inplace=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df['Start Date & Time'] = pd.to_datetime(df['Start Date & Time'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start Date & Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ...

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df['delta'] = pd.to_timedelta(df['Duration (hours)'], unit='h')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Duration (hours)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ...

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df['end datetime'] = df['Start Date & Time'] + df['delta']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Start Date & Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ...

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df.rename(columns={'Start Date & Time': 'start datetime'}, inplace=True)

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df.insert(4, 'end datetime', df.pop('end datetime'))

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#   Session Type  # CEs Needed        end datetime  Day Sobia Ansari  \
# 0         ROLE           7.0 2024-08-26 15:00:00  Mon          Yes
# 1         ROLE           7.0 2024-08-26 17:00:00  Mon          Yes
# 2         ROLE           7.0 2024-08-26 11:00:00  Mon    Scheduled
# 3         Bsci           7.0 2024-08-27 16:00:00  Tue          Yes
# 4         ROLE           7.0 2024-08-27 12:00:00  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df.rename(columns={'Start (Hrs) | Event Name | Grps': 'bigname'}, inplace=True)

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#   Session Type  # CEs Needed        end datetime  Day Sobia Ansari  \
# 0         ROLE           7.0 2024-08-26 15:00:00  Mon          Yes
# 1         ROLE           7.0 2024-08-26 17:00:00  Mon          Yes
# 2         ROLE           7.0 2024-08-26 11:00:00  Mon    Scheduled
# 3         Bsci           7.0 2024-08-27 16:00:00  Tue          Yes
# 4         ROLE           7.0 2024-08-27 12:00:00  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df[['start (dur)', 'Event','Groups']] = df['bigname'].str.split('|',n=2,expand=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bigname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ...

# %%
df.insert(0, 'title', df.pop('title'))
df.insert(1, 'start datetime', df.pop('start datetime'))
df.insert(2, 'end datetime', df.pop('end datetime'))
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
df.drop(['bigname','Start Date','Duration (hours)','AM/PM','delta', 'A', 'B', 'C', 'start (dur)', 'Event'], axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df.drop(['bigname','Start Date','Duration (hours)','AM/PM','delta', 'A', 'B', 'C', 'start (dur)', 'Event'], axis=1, inplace=True)
#       2 df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
# ...

# %%
df.to_csv('2024-06-15 CE Schedule.csv')

# %%
df.drop(['Event'], axis=1, inplace=True)
df.head()

# %%
df[df["Rahul Patwari"]=='Scheduled']
# Out:
#                                                  title      start datetime  \
# 0     M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1              M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 8          M1 PRAC Intro to Clinical Reasoning-Groups  2024-08-29 10:00:00
# 16    M2 PRAC/EDUC Clinical Reasoning Rounds with S... 2024-09-09 10:00:00
# 22    M1 ADVO Social Inequalities and Infectious Di... 2024-09-16 13:00:00
# 24      M2 SCHO EBM: Problem Sets Measurement Part 2   2024-09-18 11:00:00
# 25    M2 ADVO Trauma-Informed Care and Sexual Viole... 2024-09-18 13:00:00
# 29    M2 PROF Confidentiality 2-Mature and Emancipa... 2024-09-20 13:00:00
# 31                                      M2 PRAC BCS-2  2024-09-20 08:30:00
# 32                 M1 BSci Mononucleosis (Katie Diaz)  2024-09-23 13:00:00
# 43               M1 BSci Influenza (Kamra Thompson 1)  2024-09-30 13:00:00
# ...

# %%
df.head()
# Out:
#                                                title      start datetime  \
# 0   M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1            M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 2   M1 ADVO EQUI Health Inequities and Implicatio... 2024-08-26 09:00:00
# 3            M1 BSci Intro to Case-based Curriculum  2024-08-27 13:00:00
# 4           M1 ADVO EQUI Misuse of Race in Medicine  2024-08-27 10:00:00
#
#          end datetime Session Type  # CEs Needed  Day Sobia Ansari  \
# 0 2024-08-26 15:00:00         ROLE           7.0  Mon          Yes
# 1 2024-08-26 17:00:00         ROLE           7.0  Mon          Yes
# 2 2024-08-26 11:00:00         ROLE           7.0  Mon    Scheduled
# 3 2024-08-27 16:00:00         Bsci           7.0  Tue          Yes
# 4 2024-08-27 12:00:00         ROLE           7.0  Tue    Scheduled
#
#   Christina Chen   John Butos  Elaine Chen  ... Brett Williams Elif Yucebay  \
# ...

# %%
print(df.columns)
# Out:
# Index(['title', 'start datetime', 'end datetime', 'Session Type',
#        '# CEs Needed', 'Day', 'Sobia Ansari', 'Christina Chen', 'John Butos',
#        'Elaine Chen', 'Teresa Davis', 'Caspian Folmsbee', 'Katarzyna Gore',
#        'Stephen Gore', 'Anne Hartley', 'Scott Heinrich', 'Suchita Kishore',
#        'Matthew Kuhns', 'Carl Lambert', 'Jill Marcus', 'Irena Medenica',
#        'Sameer Panjwani', 'Melissa Rice', 'Sara Ruddock-Walker', 'Syed Shah',
#        'Andrew Simms', 'Tina Sundarum', 'Paola Susan', 'Frank Tenuto',
#        'Christine Tsai', 'Brett Williams', 'Elif Yucebay', 'Rahul Patwari',
#        'Total Column', 'Back Up', 'Scheduler', 'Reviewer', 'Notes',
#        'AS Changes', 'Groups'],
#       dtype='object')

# %%
df_rp = df[['title', 'start datetime', 'end datetime', 'Session Type','Rahul Patwari']]

# %%
df_rp_scheduled = df_rp[df["Rahul Patwari"]=="Scheduled"]
df_rp_scheduled
# Out:
#                                                  title      start datetime  \
# 0     M1 PROF Professional Identity Development and... 2024-08-26 13:00:00
# 1              M1 ADVO/COLL/PROF Small Group Dynamics  2024-08-26 15:00:00
# 8          M1 PRAC Intro to Clinical Reasoning-Groups  2024-08-29 10:00:00
# 16    M2 PRAC/EDUC Clinical Reasoning Rounds with S... 2024-09-09 10:00:00
# 22    M1 ADVO Social Inequalities and Infectious Di... 2024-09-16 13:00:00
# 24      M2 SCHO EBM: Problem Sets Measurement Part 2   2024-09-18 11:00:00
# 25    M2 ADVO Trauma-Informed Care and Sexual Viole... 2024-09-18 13:00:00
# 29    M2 PROF Confidentiality 2-Mature and Emancipa... 2024-09-20 13:00:00
# 31                                      M2 PRAC BCS-2  2024-09-20 08:30:00
# 32                 M1 BSci Mononucleosis (Katie Diaz)  2024-09-23 13:00:00
# 43               M1 BSci Influenza (Kamra Thompson 1)  2024-09-30 13:00:00
# ...

# %%
df_rp_scheduled.to_csv("rp_schedule.csv")

# %%
# SHOW SEPTEMBER DATES
top_date = pd.to_datetime('2024-09-01')
bottom_date = pd.to_datetime('2024-10-01')
sept_filter = df_rp_scheduled[(df['start datetime']>= top_date) & (df['end datetime'] < bottom_date)]
sept_filter
# Out:
# /var/folders/qs/mmc5bbzd32n4826rw9lqw39m0000gn/T/ipykernel_56209/3956073871.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sept_filter = df_rp_scheduled[(df['start datetime']>= top_date) & (df['end datetime'] < bottom_date)]
#                                                 title      start datetime  \
# 16   M2 PRAC/EDUC Clinical Reasoning Rounds with S... 2024-09-09 10:00:00
# 22   M1 ADVO Social Inequalities and Infectious Di... 2024-09-16 13:00:00
# 24     M2 SCHO EBM: Problem Sets Measurement Part 2   2024-09-18 11:00:00
# 25   M2 ADVO Trauma-Informed Care and Sexual Viole... 2024-09-18 13:00:00
# 29   M2 PROF Confidentiality 2-Mature and Emancipa... 2024-09-20 13:00:00
# 31                                     M2 PRAC BCS-2  2024-09-20 08:30:00
# 32                M1 BSci Mononucleosis (Katie Diaz)  2024-09-23 13:00:00
# 43              M1 BSci Influenza (Kamra Thompson 1)  2024-09-30 13:00:00
#
# ...

# %%
sept_filter.sort_values(by="start datetime")
# Out:
#                                                 title      start datetime  \
# 16   M2 PRAC/EDUC Clinical Reasoning Rounds with S... 2024-09-09 10:00:00
# 22   M1 ADVO Social Inequalities and Infectious Di... 2024-09-16 13:00:00
# 24     M2 SCHO EBM: Problem Sets Measurement Part 2   2024-09-18 11:00:00
# 25   M2 ADVO Trauma-Informed Care and Sexual Viole... 2024-09-18 13:00:00
# 31                                     M2 PRAC BCS-2  2024-09-20 08:30:00
# 29   M2 PROF Confidentiality 2-Mature and Emancipa... 2024-09-20 13:00:00
# 32                M1 BSci Mononucleosis (Katie Diaz)  2024-09-23 13:00:00
# 43              M1 BSci Influenza (Kamra Thompson 1)  2024-09-30 13:00:00
#
#           end datetime Session Type Rahul Patwari
# 16 2024-09-09 12:00:00      SDL/CRR     Scheduled
# 22 2024-09-16 15:00:00         ROLE     Scheduled
# 24 2024-09-18 12:00:00         ROLE     Scheduled
# 25 2024-09-18 15:00:00         ROLE     Scheduled
# ...
